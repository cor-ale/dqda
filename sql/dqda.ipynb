# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://student:pw4dqda@34.89.121.244:5432/dqda
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 'Connected: student@dqda'

# %% [markdown]
# username: 'student'
# pw: 'pw4dqda'
# IP: 34.89.121.244
# port: 5432
# database: dqda

# %%
# %sql select * from albums limit 10
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 10 rows affected.
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3),
#  (6, 'Jagged Little Pill', 4),
#  (7, 'Facelift', 5),
#  (8, 'Warner 25 Anos', 6),
#  (9, 'Plays Metallica By Four Cellos', 7),
#  (10, 'Audioslave', 8)]

# %% [markdown]
# Run query: Retrieve all the data from the tracks table. Who is the composer for track 18?

# %%
# %sql select name, milliseconds from tracks where composer = 'Wolfgang Amadeus Mozart' and album_id = 281
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 1 rows affected.
# [('"Eine Kleine Nachtmusik" Serenade In G, K. 525: I. Allegro', 348971)]

# %%
# %sql select * from tracks where milliseconds > 700000 and unit_price > 1 limit 20
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 20 rows affected.
# [(2819, 'Battlestar Galactica: The Story So Far', 226, 3, 18, None, 2622250, 490750393, Decimal('1.99')),
#  (2820, 'Occupation / Precipice', 227, 3, 19, None, 5286953, 1054423946, Decimal('1.99')),
#  (2821, 'Exodus, Pt. 1', 227, 3, 19, None, 2621708, 475079441, Decimal('1.99')),
#  (2822, 'Exodus, Pt. 2', 227, 3, 19, None, 2618000, 466820021, Decimal('1.99')),
#  (2823, 'Collaborators', 227, 3, 19, None, 2626626, 483484911, Decimal('1.99')),
#  (2824, 'Torn', 227, 3, 19, None, 2631291, 495262585, Decimal('1.99')),
#  (2825, 'A Measure of Salvation', 227, 3, 18, None, 2563938, 489715554, Decimal('1.99')),
#  (2826, 'Hero', 227, 3, 18, None, 2713755, 506896959, Decimal('1.99')),
#  (2827, 'Unfinished Business', 227, 3, 18, None, 2622038, 528499160, Decimal('1.99')),
#  (2828, 'The Passage', 227, 3, 18, None, 2623875, 490375760, Decimal('1.99')),
# ...

# %%
# %sql select * from tracks where milliseconds > 200000 and milliseconds < 500000
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 2414 rows affected.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, Decimal('0.99')),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, Decimal('0.99')),
#  (3, 'Fast As a Shark', 3, 2, 1, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 230619, 3990994, Decimal('0.99')),
#  (4, 'Restless and Wild', 3, 2, 1, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 252051, 4331779, Decimal('0.99')),
#  (5, 'Princess of the Dawn', 3, 2, 1, 'Deaffy & R.A. Smith-Diesel', 375418, 6290521, Decimal('0.99')),
#  (6, 'Put The Finger On You', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 205662, 6713451, Decimal('0.99')),
#  (7, "Let's Get It Up", 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 233926, 7636561, Decimal('0.99')),
# ...

# %%
# %sql select * from tracks where milliseconds between 200000 and 4000000 limit 10
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 10 rows affected.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, Decimal('0.99')),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, Decimal('0.99')),
#  (3, 'Fast As a Shark', 3, 2, 1, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 230619, 3990994, Decimal('0.99')),
#  (4, 'Restless and Wild', 3, 2, 1, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 252051, 4331779, Decimal('0.99')),
#  (5, 'Princess of the Dawn', 3, 2, 1, 'Deaffy & R.A. Smith-Diesel', 375418, 6290521, Decimal('0.99')),
#  (6, 'Put The Finger On You', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 205662, 6713451, Decimal('0.99')),
#  (7, "Let's Get It Up", 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 233926, 7636561, Decimal('0.99')),
# ...

# %%
% sql select * from tracks where composer is null limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, Decimal('0.99')),
#  (63, 'Desafinado', 8, 1, 2, None, 185338, 5990473, Decimal('0.99')),
#  (64, 'Garota De Ipanema', 8, 1, 2, None, 285048, 9348428, Decimal('0.99'))]

# %%
% sql select count(*) from tracks where composer is null
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 1 rows affected.
# [(978,)]

# %%
% sql select * from tracks where genre_id <> 1 and  genre_id <> 2 limit 2
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 2 rows affected.
# [(77, 'Enter Sandman', 9, 1, 3, 'Apocalyptica', 221701, 7286305, Decimal('0.99')),
#  (78, 'Master Of Puppets', 9, 1, 3, 'Apocalyptica', 436453, 14375310, Decimal('0.99'))]

# %%
# %sql select * from genres where id = 1 or id =2
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 2 rows affected.
# [(1, 'Rock'), (2, 'Jazz')]

# %% [markdown]
# Genre = 1 oder 2 und Unit_price = 0.99 ?

# %%
% sql select * from tracks where genre_id = 1 or genre_id = 2 limit 2
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 2 rows affected.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, Decimal('0.99')),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, Decimal('0.99'))]

# %% [markdown]
# Selecting all tracks that have unit price = 0.99
# or all tracks that are priced with 1.99 and at the same time have genre_id =3

# %%
# %sql select * from tracks where unit_price = 0.99 or ( unit_price = 1.99 and genre_id =3) limit 2;
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 2 rows affected.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, Decimal('0.99')),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, Decimal('0.99'))]

# %%
# %sql select * from tracks where genre_id in (1,2,3) limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, Decimal('0.99')),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, Decimal('0.99')),
#  (3, 'Fast As a Shark', 3, 2, 1, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 230619, 3990994, Decimal('0.99'))]

# %%
# %sql select * from tracks where genre_id not in (1,2,3) limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(99, 'Your Time Has Come', 11, 1, 4, 'Cornell, Commerford, Morello, Wilk', 255529, 8273592, Decimal('0.99')),
#  (100, 'Out Of Exile', 11, 1, 4, 'Cornell, Commerford, Morello, Wilk', 291291, 9506571, Decimal('0.99')),
#  (101, 'Be Yourself', 11, 1, 4, 'Cornell, Commerford, Morello, Wilk', 279484, 9106160, Decimal('0.99'))]

# %%
# %sql select * from tracks where name like '%you'
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 1 rows affected.
# [(697, 'Born On The Bayou', 55, 1, 1, 'J.C. Fogerty', 316630, 10361866, Decimal('0.99'))]

# %%
# %sql select * from tracks where lower(name) like '%you%' limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, Decimal('0.99')),
#  (6, 'Put The Finger On You', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 205662, 6713451, Decimal('0.99')),
#  (39, 'You Oughta Know', 6, 1, 1, 'Alanis Morissette & Glenn Ballard', 249234, 8196916, Decimal('0.99'))]

# %%
# %sql select * from tracks where lower(name) like 'you%' limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(39, 'You Oughta Know', 6, 1, 1, 'Alanis Morissette & Glenn Ballard', 249234, 8196916, Decimal('0.99')),
#  (44, 'You Learn', 6, 1, 1, 'Alanis Morissette & Glenn Ballard', 239699, 7824837, Decimal('0.99')),
#  (50, 'You Oughta Know (Alternate)', 6, 1, 1, 'Alanis Morissette & Glenn Ballard', 491885, 16008629, Decimal('0.99'))]

# %%
# %sql select * from tracks order by milliseconds limit 5
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 5 rows affected.
# [(2461, 'É Uma Partida De Futebol', 200, 1, 1, 'Samuel Rosa', 1071, 38747, Decimal('0.99')),
#  (168, 'Now Sports', 18, 1, 4, None, 4884, 161266, Decimal('0.99')),
#  (170, 'A Statistic', 18, 1, 4, None, 6373, 211997, Decimal('0.99')),
#  (178, 'Oprah', 18, 1, 4, None, 6635, 224313, Decimal('0.99')),
#  (3304, 'Commercial 1', 258, 1, 17, 'L. Muggerud', 7941, 319888, Decimal('0.99'))]

# %%
# %sql select * from tracks order by milliseconds desc limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(2820, 'Occupation / Precipice', 227, 3, 19, None, 5286953, 1054423946, Decimal('1.99')),
#  (3224, 'Through a Looking Glass', 229, 3, 21, None, 5088838, 1059546140, Decimal('1.99')),
#  (3244, 'Greetings from Earth, Pt. 1', 253, 3, 20, None, 2960293, 536824558, Decimal('1.99'))]

# %%
# %sql select * from tracks order by 2 desc limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(2926, 'Zoo Station', 232, 1, 1, 'U2', 276349, 9056902, Decimal('0.99')),
#  (3028, 'Zooropa', 240, 1, 1, 'U2; Bono', 392359, 12807979, Decimal('0.99')),
#  (968, 'Zombie Eaters', 77, 1, 4, 'Faith No More', 360881, 11835367, Decimal('0.99'))]

# %%
# %sql select * from tracks order by milliseconds, unit_price desc limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(2461, 'É Uma Partida De Futebol', 200, 1, 1, 'Samuel Rosa', 1071, 38747, Decimal('0.99')),
#  (168, 'Now Sports', 18, 1, 4, None, 4884, 161266, Decimal('0.99')),
#  (170, 'A Statistic', 18, 1, 4, None, 6373, 211997, Decimal('0.99'))]

# %% [markdown]
# Sort tracks by price and length descending

# %%
# %sql select * from tracks order by milliseconds desc, unit_price desc limit 3
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 3 rows affected.
# [(2820, 'Occupation / Precipice', 227, 3, 19, None, 5286953, 1054423946, Decimal('1.99')),
#  (3224, 'Through a Looking Glass', 229, 3, 21, None, 5088838, 1059546140, Decimal('1.99')),
#  (3244, 'Greetings from Earth, Pt. 1', 253, 3, 20, None, 2960293, 536824558, Decimal('1.99'))]

# %% [markdown]
# Run Query: Retrieve all data from the artists table. Look at the list of artists, how many artists are you familiar with (there is no wrong answer here)?

# %%
# %sql select * from artists limit 5
# Out:
#  * postgresql://student:***@34.89.121.244:5432/dqda
# 5 rows affected.
# [(1, 'AC/DC'),
#  (2, 'Accept'),
#  (3, 'Aerosmith'),
#  (4, 'Alanis Morissette'),
#  (5, 'Alice In Chains')]

# %% [markdown]
# Run Query: Retrieve all data from the invoices table. What is the billing address for customer 31?

# %% [markdown]
# Run Query: Return the playlist id, and name from the playlists table. How many playlists are there? Which would you classify is your favorite from this list?

# %% [markdown]
# Run Query: Return the Customer Id, Invoice Date, and Billing City from the Invoices table. What city is associated with Customer ID number 42? What was the invoice date for the customer in Santiago?

# %% [markdown]
# Run Query: Return the First Name, Last Name, Email, and Phone, from the Customers table. What is the telephone number for Jennifer Peterson?

# %% [markdown]
# Run Query: Return the Track Id, Genre Id, Composer, Unit Price from the Tracks table. How much do these tracks cost?

# %% [markdown]
# Run Query: Select all the columns from the Playlist Track table and limit the results to 10 records. How might this information be used?

# %% [markdown]
# Run Query: Select all the columns from the Media Types table and limit the results to 50 records. What happened when you ran this query? Were you able to get all 50 records?

# %% [markdown]
# Run Query: Select all the columns from the Albums table and limit the results to 5 records. How many columns are in the albums table?

# %% [markdown]
# **Short Quiz**

# %% [markdown]
# Retrieve all the records from the Employees table. What is Robert King's mailing address?

# %% [markdown]
# Retrieve the FirstName, LastName, Birthdate, Address, City, and State from the Employees table. **Which of the employees listed below has a birthdate of 3-3-1965?**

# %% [markdown]
# Retrieve all the columns from the Tracks table, but only return 20 rows. **What is the runtime in milliseconds for the 5th track, entitled "Princess of the Dawn"? Note: You will need to scroll to the right to see it, and you may want to copy and paste the number to ensure it is entered correctly.**

# %% [markdown]
# Run Query: Find all the tracks that have a length of 5,000,000 milliseconds or more. **How many tracks are returned?**

# %% [markdown]
# Run Query: Find all the invoices whose total is between 5 and 15 dollars.

# %% [markdown]
# Run Query: Find all the customers from the following States: RJ, DF, AB, BC, CA, WA, NY.

# %% [markdown]
# What company does Jack Smith work for?

# %% [markdown]
# Run Query: Find all the invoices for customer 56 and 58 where the total was between 1.00 and 5.00 dollars.

# %% [markdown]
# What was the invoice date for invoice ID 315?

# %% [markdown]
# Run Query: Find all the tracks whose name starts with 'All'. **How many total records there are for this query?**

# %% [markdown]
# Run Query: Find all the customer emails that start with "J" and are from gmail.com.

# %% [markdown]
# **HW End**

# %% [markdown]
# Run Query: Find all the invoices from the billing city Brasília, Edmonton, and Vancouver and sort in descending order by invoice ID.

# %% [markdown]
# Run Query: Show the number of orders placed by each customer (hint: this is found in the invoices table) and sort the result by the number of orders in descending order. **What is the number of items placed for the 8th person on this list?**

# %% [markdown]
# Run Query: Find the albums with 12 or more tracks.

# %% [markdown]
# until here

# %% [markdown]
#  How many albums does the artist Led Zeppelin have?

# %% [markdown]
# Create a list of album titles and the unit prices for the artist "Audioslave". **How many records are returned?**

# %% [markdown]
#  Find the first and last name of any customer who does not have an invoice. Are there any customers returned from the query?

# %% [markdown]
# Find the total price for each album.

# %% [markdown]
# What is the total price for the album “Big Ones”?

# %% [markdown]
# How many records are created when you apply a Cartesian join to the invoice and invoice items table?

# %% [markdown]
# Using a subquery, find the names of all the tracks for the album "Californication".

# %% [markdown]
# Find the total number of invoices for each customer along with the customer's full name, city and email.

# %% [markdown]
# After running the query described above, what is the email address of the 5th person, František Wichterlová?

# %% [markdown]
# Retrieve the track name, album, artistID, and trackID for all the albums.

# %% [markdown]
# What is the song title of trackID 12 from the "For Those About to Rock We Salute You" ?

# %% [markdown]
# Retrieve a list with the managers last name, and the last name of the employees who report to him or her. **Who are the reports for the manager named Mitchell?**

# %% [markdown]
# Find the name and ID of the artists who do not have albums.

# %% [markdown]
# Use a UNION to create a list of all the employee's and customer's first names and last names ordered by the last name in descending order. **Determine what is the last name of the 6th record** Remember to order things in descending order to be sure to get the correct answer.

# %% [markdown]
# See if there are any customers who have a different city listed in their billing city versus their customer city.
